# %%
import os
import tensorflow_data_validation as tfdv

# %%
root_bucket='gs://lf-ml-demo-us-c1/taxi-fare/20190402'

# %%
statistics = tfdv.load_statistics(input_path=os.path.join(root_bucket, 'tfdv_output', 'exploration_stats.tfrecord'))
# Out:
# WARNING:tensorflow:From /Users/lfloretta/DevTool/miniconda3/envs/end2end/lib/python2.7/site-packages/tensorflow_data_validation/utils/stats_gen_lib.py:328: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`

# %%
tfdv.visualize_statistics(statistics)
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.contentWindow.document.write(facets_html);
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %%
# %%bigquery
# SELECT
#   *
# FROM
#   `bigquery-public-data.chicago_taxi_trips.taxi_trips`
# LIMIT 5
# Out:
# UsageError: Cell magic `%%bigquery` not found.
